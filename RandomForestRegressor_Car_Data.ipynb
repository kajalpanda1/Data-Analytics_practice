# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-0c64d736-9dd4-491c-a499-e92a9f65d632" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0c64d736-9dd4-491c-a499-e92a9f65d632">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving car data.csv to car data.csv
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

# %%
df_car=pd.read_csv('car data.csv')

# %%
df_car.head()
# Out:
#   Car_Name  Year  Selling_Price  ...  Seller_Type  Transmission Owner
# 0     ritz  2014           3.35  ...       Dealer        Manual     0
# 1      sx4  2013           4.75  ...       Dealer        Manual     0
# 2     ciaz  2017           7.25  ...       Dealer        Manual     0
# 3  wagon r  2011           2.85  ...       Dealer        Manual     0
# 4    swift  2014           4.60  ...       Dealer        Manual     0
#
# [5 rows x 9 columns]

# %%
df_car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
df_car.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
df_car['Old']=2020-df_car['Year']
df_car.drop(columns=['Car_Name','Year'],inplace=True)

# %%
df_car.columns
# Out:
# Index(['Selling_Price', 'Present_Price', 'Kms_Driven', 'Fuel_Type',
#        'Seller_Type', 'Transmission', 'Owner', 'Old'],
#       dtype='object')

# %%
df_car.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven  ... Transmission Owner Old
# 0           3.35           5.59       27000  ...       Manual     0   6
# 1           4.75           9.54       43000  ...       Manual     0   7
# 2           7.25           9.85        6900  ...       Manual     0   3
# 3           2.85           4.15        5200  ...       Manual     0   9
# 4           4.60           6.87       42450  ...       Manual     0   6
#
# [5 rows x 8 columns]

# %%
df_car.Fuel_Type.unique()
# Out:
# array(['Petrol', 'Diesel', 'CNG'], dtype=object)

# %%
df_car. Seller_Type.unique()
# Out:
# array(['Dealer', 'Individual'], dtype=object)

# %%
df_car.Transmission.unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
df_car=pd.get_dummies(df_car)

# %%
df_car
# Out:
#      Selling_Price  Present_Price  ...  Transmission_Automatic  Transmission_Manual
# 0             3.35           5.59  ...                       0                    1
# 1             4.75           9.54  ...                       0                    1
# 2             7.25           9.85  ...                       0                    1
# 3             2.85           4.15  ...                       0                    1
# 4             4.60           6.87  ...                       0                    1
# ..             ...            ...  ...                     ...                  ...
# 296           9.50          11.60  ...                       0                    1
# 297           4.00           5.90  ...                       0                    1
# 298           3.35          11.00  ...                       0                    1
# 299          11.50          12.50  ...                       0                    1
# ...

# %%
features=df_car.iloc[:,1:]
features.shape
# Out:
# (301, 11)

# %%
target=df_car.iloc[:,0:1]
target.shape
# Out:
# (301, 1)

# %%
features, target
# Out:
# (     Present_Price  Kms_Driven  ...  Transmission_Automatic  Transmission_Manual
#  0             5.59       27000  ...                       0                    1
#  1             9.54       43000  ...                       0                    1
#  2             9.85        6900  ...                       0                    1
#  3             4.15        5200  ...                       0                    1
#  4             6.87       42450  ...                       0                    1
#  ..             ...         ...  ...                     ...                  ...
#  296          11.60       33988  ...                       0                    1
#  297           5.90       60000  ...                       0                    1
#  298          11.00       87934  ...                       0                    1
#  299          12.50        9000  ...                       0                    1
# ...

# %%
X_train,X_test,y_train,y_test=train_test_split(features,target,test_size=0.2,random_state=0)

# %%
X_train.shape
# Out:
# (240, 11)

# %%
y_train=np.ravel(y_train)

# %%
model = RandomForestRegressor(n_estimators=600)
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=600, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
y_pred_rf = model.predict(X_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred_rf)
# Out:
# 0.9562808607805788

# %%
X_test[0:1]
# Out:
#      Present_Price  Kms_Driven  ...  Transmission_Automatic  Transmission_Manual
# 223            9.4       61381  ...                       0                    1
#
# [1 rows x 11 columns]

# %%
new_test=np.array([8.5,26000,1,2,0,1,0,0,1,1,0])

# %%
sell_price=model.predict(new_test.reshape(1,-1))

# %%
print('The value of the car is:',new_pred)
# Out:
# The value of the car is: [6.98866667]
